# %%
import warnings
from PIL import Image, ImageEnhance
warnings.filterwarnings('ignore')
import tensorflow as tf
from keras.models import load_model
from keras.applications.vgg16 import preprocess_input
import numpy as np
from keras.preprocessing import image

from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import QFileDialog
from PyQt5.QtGui import QMovie
from PyQt5.QtWidgets import QMessageBox

from win32com.client import Dispatch


def speak(str1):
    speak=Dispatch(("SAPI.SpVoice"))
    speak.Speak(str1)

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(695, 609)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.frame = QtWidgets.QFrame(self.centralwidget)
        self.frame.setGeometry(QtCore.QRect(0, 0, 701, 611))
        self.frame.setStyleSheet("background-color: #035874;")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(80, -60, 541, 561))
        self.label.setText("")
        self.gif=QMovie("picture.gif")
        self.label.setMovie(self.gif)
        self.gif.start()
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(self.frame)
        self.label_2.setGeometry(QtCore.QRect(80, 430, 591, 41))
        font = QtGui.QFont()
        font.setPointSize(24)
        font.setBold(True)
        font.setWeight(75)
        self.label_2.setFont(font)
        self.label_2.setObjectName("label_2")
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(30, 530, 201, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        icon = QtGui.QIcon()
        icon.addPixmap(QtGui.QPixmap("patient.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        MainWindow.setWindowIcon(icon)
        self.pushButton.setFont(font)
        self.pushButton.setStyleSheet("QPushButton{\n"
"border-radius: 10px;\n"
" background-color:#DF582C;\n"
"\n"
"}\n"
"QPushButton:hover {\n"
" background-color: #7D93E0;\n"
"}")
        self.pushButton.setObjectName("pushButton")
        self.pushButton_2 = QtWidgets.QPushButton(self.frame)
        self.pushButton_2.setGeometry(QtCore.QRect(450, 530, 201, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_2.setFont(font)
        self.pushButton_2.setStyleSheet("QPushButton{\n"
"border-radius: 10px;\n"
" background-color:#DF582C;\n"
"\n"
"}\n"
"QPushButton:hover {\n"
" background-color: #29362c;\n"
"}")
        self.pushButton_2.setObjectName("pushButton_2")
        MainWindow.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        self.pushButton.clicked.connect(self.upload_image)
        self.pushButton_2.clicked.connect(self.predict_result)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "PNEUMONIA Detection Apps"))
        self.label.setToolTip(_translate("MainWindow", "<html><head/><body><p><img src=\":/newPrefix/picture.gif\"/></p></body></html>"))
        self.label_2.setText(_translate("MainWindow", "PNEUMONIA Detection"))
        self.pushButton.setText(_translate("MainWindow", "Upload Image"))
        self.pushButton_2.setText(_translate("MainWindow", "Prediction"))
    def __init__(self):
        self.result = None  

    

    def upload_image(self):
        filename = QFileDialog.getOpenFileName()
        path = filename[0]
        path = str(path)
        print(path)
        model = load_model('chest_xray.h5') 
        img_file = image.load_img(path, target_size=(224, 224))
        x = image.img_to_array(img_file)
        x = np.expand_dims(x, axis=0)
        img_data = preprocess_input(x)
        self.result = model.predict(img_data)  

    def prompt_upload_image(self):
        speak("Please upload an image first.")

    def predict_result(self):
        if self.result is None:  
            self.prompt_upload_image()
            return
        
        print(self.result)
        if self.result[0][0] > 0.5:
            print("Result is Normal")
            speak("Good news you are not affected.")
        else:
            print("Affected By PNEUMONIA")
            speak("Bad news you are affected by PNEUMONIA")


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
import warnings
from PIL import Image, ImageEnhance
warnings.filterwarnings('ignore')
import tensorflow as tf
from keras.models import load_model
from keras.applications.vgg16 import preprocess_input
import numpy as np
from keras.preprocessing import image

from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import QFileDialog, QLabel

from win32com.client import Dispatch

def speak(str1):
    speak=Dispatch(("SAPI.SpVoice"))
    speak.Speak(str1)

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(695, 609)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        
        # Set background image
        self.background = QLabel(self.centralwidget)
        self.background.setGeometry(QtCore.QRect(0, 0, 695, 609))
        self.background.setPixmap(QtGui.QPixmap("Xray.jpeg"))  # Set your background image here
        self.background.setScaledContents(True)
        
        self.frame = QtWidgets.QFrame(self.centralwidget)
        self.frame.setGeometry(QtCore.QRect(50, 50, 601, 501))
        self.frame.setStyleSheet("background-color: rgba(255, 255, 255, 200);\n"
"border-radius: 20px;")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(150, 30, 301, 301))
        self.label.setText("")
        self.label.setObjectName("label")
        
        self.label_2 = QtWidgets.QLabel(self.frame)
        self.label_2.setGeometry(QtCore.QRect(150, 370, 301, 31))
        font = QtGui.QFont()
        font.setPointSize(14)
        font.setBold(True)
        self.label_2.setFont(font)
        self.label_2.setObjectName("label_2")
        
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(80, 440, 181, 41))
        self.pushButton.setObjectName("pushButton")
        
        self.pushButton_2 = QtWidgets.QPushButton(self.frame)
        self.pushButton_2.setGeometry(QtCore.QRect(330, 440, 181, 41))
        self.pushButton_2.setObjectName("pushButton_2")
        
        self.prediction_label = QtWidgets.QLabel(self.frame)
        self.prediction_label.setGeometry(QtCore.QRect(150, 410, 301, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        self.prediction_label.setFont(font)
        self.prediction_label.setObjectName("prediction_label")
        
        MainWindow.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        self.pushButton.clicked.connect(self.upload_image)
        self.pushButton_2.clicked.connect(self.predict_result)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "PNEUMONIA Detection App"))
        self.label_2.setText(_translate("MainWindow", "PNEUMONIA Detection"))
        self.pushButton.setText(_translate("MainWindow", "Upload Image"))
        self.pushButton_2.setText(_translate("MainWindow", "Predict"))
        self.prediction_label.setText(_translate("MainWindow", ""))

    def upload_image(self):
        filename, _ = QFileDialog.getOpenFileName()
        path = str(filename)
        if path:
            self.image_path = path
            pixmap = QtGui.QPixmap(path)
            self.label.setPixmap(pixmap.scaled(301, 301, QtCore.Qt.KeepAspectRatio))
            self.prediction_label.setText("")

    def prompt_upload_image(self):
        speak("Please upload an image first.")

    def predict_result(self):
        if not hasattr(self, 'image_path'):
            self.prompt_upload_image()
            return

        model = load_model('chest_xray.h5') 
        img_file = image.load_img(self.image_path, target_size=(224, 224))
        x = image.img_to_array(img_file)
        x = np.expand_dims(x, axis=0)
        img_data = preprocess_input(x)
        result = model.predict(img_data)

        if result[0][0] > 0.5:
            self.prediction_label.setText("Result: Normal")
            speak("Good news! You are not affected.")
        else:
            self.prediction_label.setText("Result: Affected by PNEUMONIA")
            speak("Bad news! You are affected by PNEUMONIA")

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
import warnings
from PIL import Image, ImageEnhance
warnings.filterwarnings('ignore')
import tensorflow as tf
from keras.models import load_model
from keras.applications.vgg16 import preprocess_input
import numpy as np
from keras.preprocessing import image

from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import QFileDialog, QLabel

from win32com.client import Dispatch

def speak(str1):
    speak=Dispatch(("SAPI.SpVoice"))
    speak.Speak(str1)

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(695, 609)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        
        # Set background image
        self.background = QLabel(self.centralwidget)
        self.background.setGeometry(QtCore.QRect(0, 0, 695, 609))
        self.background.setPixmap(QtGui.QPixmap("Xray.jpeg"))  # Set your background image here
        self.background.setScaledContents(True)
        
        self.frame = QtWidgets.QFrame(self.centralwidget)
        self.frame.setGeometry(QtCore.QRect(50, 50, 601, 501))
        self.frame.setStyleSheet("background-color: rgba(255, 255, 255, 200);\n"
"border-radius: 20px;")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(150, 30, 301, 301))
        self.label.setText("")
        self.label.setObjectName("label")
        
        self.label_2 = QtWidgets.QLabel(self.frame)
        self.label_2.setGeometry(QtCore.QRect(150, 370, 301, 31))
        font = QtGui.QFont()
        font.setPointSize(14)
        font.setBold(True)
        self.label_2.setFont(font)
        self.label_2.setObjectName("label_2")
        
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(80, 440, 181, 41))
        self.pushButton.setObjectName("pushButton")
        
        self.pushButton_2 = QtWidgets.QPushButton(self.frame)
        self.pushButton_2.setGeometry(QtCore.QRect(330, 440, 181, 41))
        self.pushButton_2.setObjectName("pushButton_2")
        
        self.prediction_label = QtWidgets.QLabel(self.frame)
        self.prediction_label.setGeometry(QtCore.QRect(150, 410, 301, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        self.prediction_label.setFont(font)
        self.prediction_label.setObjectName("prediction_label")

        self.radio_pneumonia = QtWidgets.QRadioButton(self.frame)
        self.radio_pneumonia.setGeometry(QtCore.QRect(80, 380, 121, 20))
        self.radio_pneumonia.setObjectName("radio_pneumonia")
        self.radio_pneumonia.setChecked(True)
        self.radio_pneumonia.setText("Pneumonia")

        self.radio_covid = QtWidgets.QRadioButton(self.frame)
        self.radio_covid.setGeometry(QtCore.QRect(330, 380, 91, 20))
        self.radio_covid.setObjectName("radio_covid")
        self.radio_covid.setText("COVID-19")
        
        MainWindow.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        self.pushButton.clicked.connect(self.upload_image)
        self.pushButton_2.clicked.connect(self.predict_result)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "PNEUMONIA Detection App"))
        self.label_2.setText(_translate("MainWindow", "PNEUMONIA Detection"))
        self.pushButton.setText(_translate("MainWindow", "Upload Image"))
        self.pushButton_2.setText(_translate("MainWindow", "Predict"))
        self.prediction_label.setText(_translate("MainWindow", ""))
        self.radio_pneumonia.setText(_translate("MainWindow", "Pneumonia"))
        self.radio_covid.setText(_translate("MainWindow", "COVID-19"))

    def upload_image(self):
        filename, _ = QFileDialog.getOpenFileName()
        path = str(filename)
        if path:
            self.image_path = path
            pixmap = QtGui.QPixmap(path)
            self.label.setPixmap(pixmap.scaled(301, 301, QtCore.Qt.KeepAspectRatio))
            self.prediction_label.setText("")

    def prompt_upload_image(self):
        speak("Please upload an image first.")

    def predict_result(self):
        if not hasattr(self, 'image_path'):
            self.prompt_upload_image()
            return

        if self.radio_pneumonia.isChecked():
            model_path = 'chest_xray.h5'
        elif self.radio_covid.isChecked():
            model_path = 'last.h5'
        else:
            self.prediction_label.setText("Please select a disease.")
            return

        model = load_model(model_path)
        img_file = image.load_img(self.image_path, target_size=(224, 224))
        x = image.img_to_array(img_file)
        x = np.expand_dims(x, axis=0)
        img_data = preprocess_input(x)
        result = model.predict(img_data)

        if result[0][0] < 0.5:
            if self.radio_pneumonia.isChecked():
                self.prediction_label.setText("Result: Affected by PNEUMONIA")
                speak("Bad news! You are affected by PNEUMONIA")
            else:
                self.prediction_label.setText("Result: Positive for COVID-19")
                speak("You are tested positive for COVID-19")
        else:
            if self.radio_pneumonia.isChecked():
                self.prediction_label.setText("Result: Normal")
                speak("Good news! You are not affected.")
            else:
                self.prediction_label.setText("Result: Negative for COVID-19")
                speak("You are tested negative for COVID-19")

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 121, in Ui_MainWindow.predict_result(self)
#     118     self.prediction_label.setText("Please select a disease.")
#     119     return
# --> 121 model = load_model(model_path)
#     122 img_file = image.load_img(self.image_path, target_size=(224, 224))
#     123 x = image.img_to_array(img_file)
#
# File ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:183, in load_model(filepath, custom_objects, compile, safe_mode)
#     176     return saving_lib.load_model(
#     177         filepath,
#     178         custom_objects=custom_objects,
#     179         compile=compile,
#     180         safe_mode=safe_mode,
#     181     )
#     182 if str(filepath).endswith((".h5", ".hdf5")):
# --> 183     return legacy_h5_format.load_model_from_hdf5(filepath)
#     184 elif str(filepath).endswith(".keras"):
# ...

# %%
import warnings
from PIL import Image, ImageEnhance
warnings.filterwarnings('ignore')
import tensorflow as tf
from keras.models import load_model
from keras.applications.vgg16 import preprocess_input
import numpy as np
from keras.preprocessing import image

from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import QFileDialog, QLabel

from win32com.client import Dispatch

def speak(str1):
    speak=Dispatch(("SAPI.SpVoice"))
    speak.Speak(str1)

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(695, 609)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        
        # Set background image
        self.background = QLabel(self.centralwidget)
        self.background.setGeometry(QtCore.QRect(0, 0, 695, 609))
        self.background.setPixmap(QtGui.QPixmap("Xray.jpeg"))  # Set your background image here
        self.background.setScaledContents(True)
        
        self.frame = QtWidgets.QFrame(self.centralwidget)
        self.frame.setGeometry(QtCore.QRect(50, 50, 601, 501))
        self.frame.setStyleSheet("background-color: rgba(255, 255, 255, 200);\n"
"border-radius: 20px;")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(150, 50, 301, 301))
        self.label.setText("")
        self.label.setObjectName("label")
        
        self.label_2 = QtWidgets.QLabel(self.frame)
        self.label_2.setGeometry(QtCore.QRect(150, 20, 301, 31))
        font = QtGui.QFont()
        font.setPointSize(14)
        font.setBold(True)
        self.label_2.setFont(font)
        self.label_2.setObjectName("label_2")
        
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(80, 440, 181, 41))
        self.pushButton.setObjectName("pushButton")
        
        self.pushButton_2 = QtWidgets.QPushButton(self.frame)
        self.pushButton_2.setGeometry(QtCore.QRect(330, 440, 181, 41))
        self.pushButton_2.setObjectName("pushButton_2")
        
        self.prediction_label = QtWidgets.QLabel(self.frame)
        self.prediction_label.setGeometry(QtCore.QRect(150, 410, 301, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        self.prediction_label.setFont(font)
        self.prediction_label.setObjectName("prediction_label")

        self.radio_pneumonia = QtWidgets.QRadioButton(self.frame)
        self.radio_pneumonia.setGeometry(QtCore.QRect(50, 380, 200, 40))
        self.radio_pneumonia.setObjectName("radio_pneumonia")
        self.radio_pneumonia.setChecked(True)
        self.radio_pneumonia.setText("Pneumonia")
        self.radio_pneumonia.setStyleSheet("font-size: 16px;")

        self.radio_covid = QtWidgets.QRadioButton(self.frame)
        self.radio_covid.setGeometry(QtCore.QRect(300, 380, 200, 40))
        self.radio_covid.setObjectName("radio_covid")
        self.radio_covid.setText("COVID-19")
        self.radio_covid.setStyleSheet("font-size: 16px;")
        
        MainWindow.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        self.pushButton.clicked.connect(self.upload_image)
        self.pushButton_2.clicked.connect(self.predict_result)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "X_ray Detection App"))
        self.label_2.setText(_translate("MainWindow", "PNEUMONIA Detection"))
        self.pushButton.setText(_translate("MainWindow", "Upload Image"))
        self.pushButton_2.setText(_translate("MainWindow", "Predict"))
        self.prediction_label.setText(_translate("MainWindow", ""))
        self.radio_pneumonia.setText(_translate("MainWindow", "Pneumonia"))
        self.radio_covid.setText(_translate("MainWindow", "COVID-19"))

    def upload_image(self):
        filename, _ = QFileDialog.getOpenFileName()
        path = str(filename)
        if path:
            self.image_path = path
            pixmap = QtGui.QPixmap(path)
            self.label.setPixmap(pixmap.scaled(301, 301, QtCore.Qt.KeepAspectRatio))
            self.prediction_label.setText("")

    def prompt_upload_image(self):
        speak("Please upload an image first.")

    def predict_result(self):
        if not hasattr(self, 'image_path'):
            self.prompt_upload_image()
            return

        if self.radio_pneumonia.isChecked():
            model_path = 'chest_xray.h5'
        elif self.radio_covid.isChecked():
            model_path = 'my_trained_model.h5'
        else:
            self.prediction_label.setText("Please select a disease.")
            return

        model = load_model(model_path)
        img_file = image.load_img(self.image_path, target_size=(224, 224))
        x = image.img_to_array(img_file)
        x = np.expand_dims(x, axis=0)
        img_data = preprocess_input(x)
        result = model.predict(img_data)

        if result[0][0] > 0.5:
            if self.radio_pneumonia.isChecked():
                self.prediction_label.setText("Result: Affected by PNEUMONIA")
                speak("Bad news! You are affected by PNEUMONIA")
            else:
                self.prediction_label.setText("Result: Positive for COVID-19")
                speak("You are tested positive for COVID-19")
        else:
            if self.radio_pneumonia.isChecked():
                self.prediction_label.setText("Result: Normal")
                speak("Good news! You are not affected.")
            else:
                self.prediction_label.setText("Result: Negative for COVID-19")
                speak("You are tested negative for COVID-19")

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
#################################### FINALLLLLLLLLLLLLLLLLLL ################################################################

# %%
import warnings
from PIL import Image, ImageEnhance
warnings.filterwarnings('ignore')
import tensorflow as tf
from keras.models import load_model
from keras.applications.vgg16 import preprocess_input
import numpy as np
from keras.preprocessing import image

from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import QFileDialog
from PyQt5.QtGui import QMovie
from PyQt5.QtWidgets import QMessageBox

from win32com.client import Dispatch


def speak(str1):
    speak=Dispatch(("SAPI.SpVoice"))
    speak.Speak(str1)

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(695, 609)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.frame = QtWidgets.QFrame(self.centralwidget)
        self.frame.setGeometry(QtCore.QRect(0, 0, 701, 611))
        self.frame.setStyleSheet("background-color: #035874;")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(80, -60, 541, 561))
        self.label.setText("")
        self.gif=QMovie("picture.gif")
        self.label.setMovie(self.gif)
        self.gif.start()
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(self.frame)
        self.label_2.setGeometry(QtCore.QRect(80, 430, 591, 41))
        font = QtGui.QFont()
        font.setPointSize(24)
        font.setBold(True)
        font.setWeight(75)
        self.label_2.setFont(font)
        self.label_2.setObjectName("label_2")
        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(30, 530, 201, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        icon = QtGui.QIcon()
        icon.addPixmap(QtGui.QPixmap("patient.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        MainWindow.setWindowIcon(icon)
        self.pushButton.setFont(font)
        self.pushButton.setStyleSheet("QPushButton{\n"
"border-radius: 10px;\n"
" background-color:#DF582C;\n"
"\n"
"}\n"
"QPushButton:hover {\n"
" background-color: #7D93E0;\n"
"}")
        self.pushButton.setObjectName("pushButton")
        self.pushButton_2 = QtWidgets.QPushButton(self.frame)
        self.pushButton_2.setGeometry(QtCore.QRect(450, 530, 201, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_2.setFont(font)
        self.pushButton_2.setStyleSheet("QPushButton{\n"
"border-radius: 10px;\n"
" background-color:#DF582C;\n"
"\n"
"}\n"
"QPushButton:hover {\n"
" background-color: #29362c;\n"
"}")
        self.pushButton_2.setObjectName("pushButton_2")

        # New button for predicting COVID
        self.pushButton_3 = QtWidgets.QPushButton(self.frame)
        self.pushButton_3.setGeometry(QtCore.QRect(240, 530, 201, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_3.setFont(font)
        self.pushButton_3.setStyleSheet("QPushButton{\n"
"border-radius: 10px;\n"
" background-color:#DF582C;\n"
"\n"
"}\n"
"QPushButton:hover {\n"
" background-color: #29362c;\n"
"}")
        self.pushButton_3.setObjectName("pushButton_3")

        MainWindow.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        self.pushButton.clicked.connect(self.upload_image)
        self.pushButton_2.clicked.connect(self.predict_result)
        self.pushButton_3.clicked.connect(self.upload_image_covid)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "PNEUMONIA Detection Apps"))
        self.label.setToolTip(_translate("MainWindow", "<html><head/><body><p><img src=\":/newPrefix/picture.gif\"/></p></body></html>"))
        self.label_2.setText(_translate("MainWindow", "PNEUMONIA Detection"))
        self.pushButton.setText(_translate("MainWindow", "Upload Image"))
        self.pushButton_2.setText(_translate("MainWindow", "Prediction"))
        self.pushButton_3.setText(_translate("MainWindow", "Predict COVID"))

    def __init__(self):
        self.result = None  

    def upload_image(self):
        filename = QFileDialog.getOpenFileName()
        path = filename[0]
        path = str(path)
        print(path)
        model = load_model('chest_xray.h5') 
        img_file = image.load_img(path, target_size=(224, 224))
        x = image.img_to_array(img_file)
        x = np.expand_dims(x, axis=0)
        img_data = preprocess_input(x)
        self.result = model.predict(img_data)  

    def upload_image_covid(self):
        filename = QFileDialog.getOpenFileName()
        path = filename[0]
        path = str(path)
        print(path)
        model = load_model('yup.h5') 
        img_file = image.load_img(path, target_size=(75, 75))
        x = image.img_to_array(img_file)
        x = np.expand_dims(x, axis=0)
        img_data = preprocess_input(x)
        self.result = model.predict(img_data)  
        self.predict_result_covid() 

    def prompt_upload_image(self):
        speak("Please upload an image first.")

    def predict_result(self):
        if self.result is None:  
            self.prompt_upload_image()
            return
        
        print(self.result)
        if self.result[0][0] > 0.5:
            print("Result is Normal")
            speak("Good news you are not affected.")
        else:
            print("Affected By PNEUMONIA")
            speak("Bad news you are affected by PNEUMONIA")

    def predict_result_covid(self):
        if self.result is None:  
            self.prompt_upload_image()
            return
        
        print(self.result)
        if self.result[0][0] > 0.5:
            print("Result is Normal")
            speak("Good news you are not affected by COVID.")
        else:
            print("Affected By COVID")
            speak("Bad news you are affected by COVID.")

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# C:/Users/Mohamed/Downloads/x-ray/chest_xray/COVID-1.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# [[-194.37294  251.28513]]
# Affected By COVID
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
import warnings
from PIL import Image, ImageEnhance
warnings.filterwarnings('ignore')
import tensorflow as tf
from keras.models import load_model
from keras.applications.vgg16 import preprocess_input
import numpy as np
from keras.preprocessing import image

from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import QFileDialog
from PyQt5.QtGui import QMovie
from PyQt5.QtWidgets import QMessageBox

from win32com.client import Dispatch


def speak(str1):
    speak = Dispatch(("SAPI.SpVoice"))
    speak.Speak(str1)


class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(695, 609)
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.frame = QtWidgets.QFrame(self.centralwidget)
        self.frame.setGeometry(QtCore.QRect(0, 0, 701, 611))
        self.frame.setStyleSheet("background-color: #035874;")
        self.frame.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.frame.setFrameShadow(QtWidgets.QFrame.Raised)
        self.frame.setObjectName("frame")
        self.label = QtWidgets.QLabel(self.frame)
        self.label.setGeometry(QtCore.QRect(80, -60, 541, 561))
        self.label.setText("")
        self.gif = QMovie("picture.gif")
        self.label.setMovie(self.gif)
        self.gif.start()
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(self.frame)
        self.label_2.setGeometry(QtCore.QRect(80, 430, 591, 41))
        font = QtGui.QFont()
        font.setPointSize(24)
        font.setBold(True)
        font.setWeight(75)
        self.label_2.setFont(font)
        self.label_2.setObjectName("label_2")

        self.result_label = QtWidgets.QLabel(self.frame)
        self.result_label.setGeometry(QtCore.QRect(80, 480, 591, 31))
        font = QtGui.QFont()
        font.setPointSize(18)
        font.setBold(True)
        font.setWeight(75)
        self.result_label.setFont(font)
        self.result_label.setStyleSheet("color: #FFFFFF;")
        self.result_label.setObjectName("result_label")

        self.pushButton = QtWidgets.QPushButton(self.frame)
        self.pushButton.setGeometry(QtCore.QRect(30, 530, 201, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        icon = QtGui.QIcon()
        icon.addPixmap(QtGui.QPixmap("patient.png"), QtGui.QIcon.Normal, QtGui.QIcon.Off)
        MainWindow.setWindowIcon(icon)
        self.pushButton.setFont(font)
        self.pushButton.setStyleSheet("QPushButton{\n"
                                      "border-radius: 10px;\n"
                                      " background-color:#DF582C;\n"
                                      "\n"
                                      "}\n"
                                      "QPushButton:hover {\n"
                                      " background-color: #7D93E0;\n"
                                      "}")
        self.pushButton.setObjectName("pushButton")
        self.pushButton_2 = QtWidgets.QPushButton(self.frame)
        self.pushButton_2.setGeometry(QtCore.QRect(450, 530, 201, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_2.setFont(font)
        self.pushButton_2.setStyleSheet("QPushButton{\n"
                                        "border-radius: 10px;\n"
                                        " background-color:#DF582C;\n"
                                        "\n"
                                        "}\n"
                                        "QPushButton:hover {\n"
                                        " background-color: #29362c;\n"
                                        "}")
        self.pushButton_2.setObjectName("pushButton_2")

        # New button for predicting COVID
        self.pushButton_3 = QtWidgets.QPushButton(self.frame)
        self.pushButton_3.setGeometry(QtCore.QRect(240, 530, 201, 31))
        font = QtGui.QFont()
        font.setPointSize(12)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_3.setFont(font)
        self.pushButton_3.setStyleSheet("QPushButton{\n"
                                        "border-radius: 10px;\n"
                                        " background-color:#DF582C;\n"
                                        "\n"
                                        "}\n"
                                        "QPushButton:hover {\n"
                                        " background-color: #29362c;\n"
                                        "}")
        self.pushButton_3.setObjectName("pushButton_3")

        MainWindow.setCentralWidget(self.centralwidget)

        self.retranslateUi(MainWindow)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)
        self.pushButton.clicked.connect(self.upload_image)
        self.pushButton_2.clicked.connect(self.predict_result)
        self.pushButton_3.clicked.connect(self.upload_image_covid)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "PNEUMONIA & COVID Detection Apps"))
        self.label.setToolTip(_translate("MainWindow", "<html><head/><body><p><img src=\":/newPrefix/picture.gif\"/></p></body></html>"))
        self.label_2.setText(_translate("MainWindow", "PNEUMONIA & COVID Detection"))
        self.pushButton.setText(_translate("MainWindow", "Upload Image"))
        self.pushButton_2.setText(_translate("MainWindow", "Prediction"))
        self.pushButton_3.setText(_translate("MainWindow", "Predict COVID"))
        self.result_label.setText(_translate("MainWindow", ""))  # Initial empty text

    def __init__(self):
        self.result = None  

    def upload_image(self):
        filename = QFileDialog.getOpenFileName()
        path = filename[0]
        path = str(path)
        print(path)
        model = load_model('chest_xray.h5') 
        img_file = image.load_img(path, target_size=(224, 224))
        x = image.img_to_array(img_file)
        x = np.expand_dims(x, axis=0)
        img_data = preprocess_input(x)
        self.result = model.predict(img_data)  

    def upload_image_covid(self):
        filename = QFileDialog.getOpenFileName()
        path = filename[0]
        path = str(path)
        print(path)
        model = load_model('yup.h5') 
        img_file = image.load_img(path, target_size=(75, 75))
        x = image.img_to_array(img_file)
        x = np.expand_dims(x, axis=0)
        img_data = preprocess_input(x)
        self.result = model.predict(img_data)  
        self.predict_result_covid() 

    def prompt_upload_image(self):
        speak("Please upload an image first.")
        self.result_label.setText("Please upload an image first.")

    def predict_result(self):
        if self.result is None:  
            self.prompt_upload_image()
            return
        
        print(self.result)
        if self.result[0][0] > 0.5:
            message = "Your Result is Normal"
            sp = "you are not affected By PNEUMONIA"
        else:
            message = "Affected By PNEUMONIA."
            sp = "You are affected By PNEUMONIA"

        print(message)
        self.result_label.setText(message)
        speak(sp)

    def predict_result_covid(self):
        if self.result is None:  
            self.prompt_upload_image()
            return
        
        print(self.result)
        if self.result[0][0] > 0.5:
            message = "Your Result is Normal"
            sp = "you are not affected by COVID."
        else:
            message = "Affected By COVID."
            sp = "you are affected by COVID."

        print(message)
        self.result_label.setText(message)
        speak(message)


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    sys.exit(app.exec_())
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:/Users/Mohamed/Downloads/x-ray/chest_xray/val/NORMAL/NORMAL2-IM-1427-0001.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# [[1. 0.]]
# Your Result is Normal
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:/Users/Mohamed/Downloads/x-ray/chest_xray/val/PNEUMONIA/person1946_bacteria_4874.jpeg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# [[0. 1.]]
# Affected By PNEUMONIA.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# ...
